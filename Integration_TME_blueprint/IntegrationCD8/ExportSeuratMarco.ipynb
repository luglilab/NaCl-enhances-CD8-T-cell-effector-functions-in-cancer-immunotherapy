# %%
library("Seurat")
# Out:
# Attaching SeuratObject
#
# Attaching sp

# %%
library("dior")

# %%
adata = dior::read_h5(file='/home/lugli/spuccio/Projects/SP025_NaClTcell/Analysis/CD8_integrated.h5', target.object = 'seurat')

# %%
str(adata)
# Out:
# Formal class 'Seurat' [package "SeuratObject"] with 13 slots
#   ..@ assays      :List of 2
#   .. ..$ RNA   :Formal class 'Assay' [package "SeuratObject"] with 8 slots
#   .. .. .. ..@ counts       :Formal class 'dgCMatrix' [package "Matrix"] with 6 slots
#   .. .. .. .. .. ..@ i       : int [1:12438023] 33 247 349 470 490 506 511 515 542 544 ...
#   .. .. .. .. .. ..@ p       : int [1:14148] 0 488 1376 1739 2129 2821 3101 3516 3888 4594 ...
#   .. .. .. .. .. ..@ Dim     : int [1:2] 33487 14147
#   .. .. .. .. .. ..@ Dimnames:List of 2
#   .. .. .. .. .. .. ..$ : chr [1:33487] "RP11-34P13.3" "FAM138A" "OR4F5" "RP11-34P13.7" ...
#   .. .. .. .. .. .. ..$ : chr [1:14147] "BT1290_AAACGGGTCGGCCGAT" "BT1290_AAAGATGGTCGGATCC" "BT1290_AAAGATGGTTCGTGAT" "BT1290_AAAGCAACACAGTCGC" ...
#   .. .. .. .. .. ..@ x       : num [1:12438023] 2 1 1 1 1 1 1 1 4 2 ...
#   .. .. .. .. .. ..@ factors : list()
#   .. .. .. ..@ data         :Formal class 'dgCMatrix' [package "Matrix"] with 6 slots
# ...

# %%
head(adata@assays$RNA@data)
# Out:
#    [[ suppressing 14147 column names ‘BT1290_AAACGGGTCGGCCGAT’, ‘BT1290_AAAGATGGTCGGATCC’, ‘BT1290_AAAGATGGTTCGTGAT’ ... ]]
# 6 x 14147 sparse Matrix of class "dgCMatrix"
#
# RP11-34P13.3  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# FAM138A       . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# OR4F5         . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# RP11-34P13.7  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# RP11-34P13.8  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# RP11-34P13.14 . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
#
# RP11-34P13.3  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# FAM138A       . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# OR4F5         . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# RP11-34P13.7  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# ...

# %%
saveRDS(adata, "/home/lugli/spuccio/Projects/SP025_NaClTcell/Analysis/CD8_integrated.rds")

# %%
adata_raw = dior::read_h5(file='/home/lugli/spuccio/Projects/SP025_NaClTcell/Analysis/CD8_integrated_raw_counts.h5',
                          target.object = 'seurat')

# %%
saveRDS(adata_raw, "/home/lugli/spuccio/Projects/SP025_NaClTcell/Analysis/CD8_integrated_raw.rds")
